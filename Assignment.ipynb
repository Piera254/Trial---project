# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
try:
    # Load Iris dataset from sklearn
    iris = load_iris(as_frame=True)
    df = iris.frame  # Convert to pandas DataFrame
    df['species'] = df['target'].map(dict(zip(range(3), iris.target_names)))

    print("✅ Dataset loaded successfully!\n")
    
except FileNotFoundError:
    print("❌ File not found. Please check the dataset path.")
# Out:
# ✅ Dataset loaded successfully!

# %%
# Display first few rows
print("First 5 rows of the dataset:\n", df.head(), "\n")

# Check structure
print("Dataset Info:\n")
print(df.info())

print("\nMissing Values:\n", df.isnull().sum())
# Out:
# First 5 rows of the dataset:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa
#
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
# ...

# %%
# Style
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(8, 5))
for species in df['species'].unique():
    subset = df[df['species'] == species]
    plt.plot(subset.index, subset['petal length (cm)'], label=species)
plt.title("Line Chart: Petal Length across Samples")
plt.xlabel("Sample Index")
plt.ylabel("Petal Length (cm)")
plt.legend()
plt.show()

# %%
 #2. Bar Chart (Average petal length per species)
plt.figure(figsize=(6, 5))
sns.barplot(x="species", y="petal length (cm)", data=df, estimator="mean")
plt.title("Bar Chart: Average Petal Length per Species")
plt.ylabel("Average Petal Length (cm)")
plt.show()

# %%
 #3. Histogram (Distribution of sepal length)
plt.figure(figsize=(6, 5))
plt.hist(df["sepal length (cm)"], bins=15, color="skyblue", edgecolor="black")
plt.title("Histogram: Sepal Length Distribution")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
# 4. Scatter Plot (Sepal length vs Petal length)
plt.figure(figsize=(7, 5))
sns.scatterplot(x="sepal length (cm)", y="petal length (cm)", hue="species", data=df, palette="Set1")
plt.title("Scatter Plot: Sepal Length vs Petal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.legend()
plt.show()

# %% [markdown]
# ##  Key Findings ##
# 1. Iris-setosa species have distinctly smaller petals compared to versicolor and virginica.
#
# 2. The petal length shows clear separation between species, useful for classification.
#
# 3. Sepal length distribution is fairly normal, centered around 5.8 cm.
#
# 4. Scatter plots reveal strong correlation between sepal and petal length for versicolor and virginica,
#    but not for setosa.
